# %%
"""
# 修改路径：路径都是绝对路径 3个地方
1. 创建provider修改labelme_path、saved_path
2. 修改 3d_printer.yaml 中的路径
3. 修改predict路径；
4. 命令行也可以执行，需要改data yaml路径；
# !yolo task=detect mode=train model=yolov8.yaml data=./datasets/mydata.yaml epochs=200 batch=16 device='cpu'
"""

# %%
import os
import xml.dom
import numpy as np
import codecs
import json
import glob
import cv2
import shutil
import xml.etree.ElementTree as ET
import os
import os
import random
import shutil
import sys
from ultralytics import YOLO
sys.path.append('./../')
from utils.data_provider import DataProvider

# %%
# 修改对应的路径，labelme_path是训练接的路径，saved_path是xml保存路径
labelme_path = r"/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti1/"  
saved_path = r"/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/Annotations"
# data_dir = labelme_path      # 图片和标签路径
train_val_test_dir= './datasets'    # 目标文件夹
train_ratio = 0.7               # 训练集比例
val_ratio = 0.2                 # 验证集比例
test_ratio = 0.1                # 测试集比例

data_provider = DataProvider(labelme_path=labelme_path,saved_path=saved_path)
data_provider.get_img_file()
img_xmls = os.listdir(saved_path)
for img_xml in img_xmls:
    label_name = img_xml.split('.')[0]
    data_provider.convert_annotation(image_id=label_name)
# Out:
# 写入 xmlName 名称：{'version': '2.3.5', 'flags': {}, 'shapes': [{'label': 'normal', 'points': [[256.0, 197.0], [256.0, 195.0], [253.0, 192.0], [253.0, 190.0], [249.0, 187.0], [253.0, 183.0], [254.0, 171.0], [250.0, 168.0], [246.0, 168.0], [245.0, 167.0], [245.0, 163.0], [244.0, 162.0], [239.0, 164.0], [235.0, 164.0], [234.0, 163.0], [220.0, 163.0], [219.0, 164.0], [214.0, 164.0], [213.0, 165.0], [213.0, 167.0], [210.0, 169.0], [209.0, 168.0], [163.0, 168.0], [161.0, 166.0], [160.0, 162.0], [158.0, 161.0], [158.0, 162.0], [155.0, 165.0], [150.0, 167.0], [146.0, 167.0], [145.0, 168.0], [134.0, 168.0], [132.0, 167.0], [131.0, 168.0], [94.0, 169.0], [91.0, 171.0], [92.0, 173.0], [94.0, 173.0], [97.0, 175.0], [102.0, 175.0], [105.0, 177.0], [107.0, 176.0], [112.0, 176.0], [114.0, 178.0], [111.0, 180.0], [105.0, 180.0], [104.0, 181.0], [93.0, 181.0], [92.0, 182.0], [90.0, 182.0], [89.0, 181.0], [71.0, 181.0], [66.0, 183.0], [65.0, 184.0], [65.0, 186.0], [62.0, 188.0], [47.0, 188.0], [46.0, 187.0], [35.0, 187.0], [34.0, 188.0], [35.0, 190.0], [37.0, 190.0], [38.0, 191.0], [45.0, 191.0], [46.0, 192.0], [54.0, 192.0], [55.0, 193.0], [63.0, 193.0], [64.0, 194.0], [68.0, 194.0], [69.0, 193.0], [77.0, 193.0], [80.0, 195.0], [81.0, 198.0], [96.0, 198.0], [102.0, 194.0], [110.0, 193.0], [116.0, 189.0], [119.0, 189.0], [120.0, 188.0], [183.0, 188.0], [185.0, 190.0], [185.0, 194.0], [190.0, 196.0], [193.0, 196.0], [196.0, 198.0], [201.0, 198.0], [202.0, 197.0], [211.0, 197.0], [212.0, 196.0], [217.0, 195.0], [223.0, 188.0], [229.0, 194.0], [234.0, 197.0], [237.0, 197.0], [241.0, 200.0], [245.0, 200.0], [249.0, 197.0], [251.0, 197.0], [252.0, 198.0], [255.0, 198.0]], 'group_id': None, 'description': '', 'difficult': False, 'shape_type': 'polygon', 'flags': {}, 'attributes': {}}], 'imagePath': 'frame_0095.jpg', 'imageData': None, 'imageHeight': 512, 'imageWidth': 512},
#  /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/Annotations/frame_0095.xml
# 写入 xmlName 名称：{'version': '2.3.5', 'flags': {}, 'shapes': [{'label': 'spaghetti', 'points': [[82.0, 0.0], [82.0, 4.0], [91.0, 24.0], [114.0, 86.0], [126.0, 97.0], [116.0, 107.0], [116.0, 112.0], [124.0, 113.0], [128.0, 109.0], [130.0, 109.0], [143.0, 128.0], [162.0, 151.0], [165.0, 157.0], [181.0, 166.0], [198.0, 188.0], [210.0, 197.0], [214.0, 196.0], [219.0, 197.0], [222.0, 200.0], [222.0, 207.0], [225.0, 208.0], [226.0, 207.0], [225.0, 198.0], [229.0, 194.0], [236.0, 193.0], [235.0, 191.0], [229.0, 192.0], [225.0, 190.0], [227.0, 188.0], [226.0, 184.0], [223.0, 186.0], [219.0, 185.0], [221.0, 180.0], [223.0, 179.0], [225.0, 180.0], [228.0, 178.0], [209.0, 171.0], [204.0, 165.0], [200.0, 164.0], [183.0, 151.0], [176.0, 144.0], [175.0, 140.0], [172.0, 141.0], [168.0, 138.0], [154.0, 123.0], [142.0, 115.0], [137.0, 107.0], [137.0, 104.0], [144.0, 97.0], [159.0, 90.0], [171.0, 90.0], [191.0, 97.0], [194.0, 100.0], [195.0, 105.0], [208.0, 118.0], [209.0, 121.0], [208.0, 124.0], [201.0, 132.0], [196.0, 133.0], [197.0, 134.0], [201.0, 134.0], [206.0, 129.0], [208.0, 122.0], [211.0, 121.0], [221.0, 130.0], [228.0, 131.0], [240.0, 145.0], [244.0, 146.0], [246.0, 143.0], [253.0, 145.0], [252.0, 142.0], [244.0, 135.0], [241.0, 130.0], [241.0, 126.0], [233.0, 119.0], [226.0, 110.0], [218.0, 108.0], [206.0, 98.0], [199.0, 88.0], [188.0, 77.0], [187.0, 74.0], [174.0, 59.0], [158.0, 37.0], [153.0, 32.0], [143.0, 27.0], [136.0, 20.0], [121.0, 0.0]], 'group_id': None, 'description': '', 'difficult': False, 'shape_type': 'polygon', 'flags': {}, 'attributes': {}}], 'imagePath': 'frame_0195.jpg', 'imageData': None, 'imageHeight': 512, 'imageWidth': 512},
#  /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/Annotations/frame_0195.xml
# 写入 xmlName 名称：{'version': '2.3.5', 'flags': {}, 'shapes': [{'label': 'spaghetti', 'points': [[160.0, 65.0], [159.0, 66.0], [159.0, 73.0], [160.0, 74.0], [160.0, 76.0], [166.0, 82.0], [166.0, 83.0], [168.0, 85.0], [168.0, 87.0], [169.0, 88.0], [169.0, 90.0], [171.0, 92.0], [172.0, 92.0], [173.0, 93.0], [173.0, 94.0], [175.0, 96.0], [175.0, 97.0], [177.0, 99.0], [177.0, 100.0], [180.0, 103.0], [181.0, 106.0], [183.0, 108.0], [183.0, 109.0], [184.0, 110.0], [184.0, 111.0], [186.0, 114.0], [186.0, 118.0], [187.0, 119.0], [187.0, 121.0], [189.0, 123.0], [189.0, 130.0], [191.0, 132.0], [192.0, 132.0], [193.0, 133.0], [193.0, 134.0], [194.0, 134.0], [197.0, 137.0], [197.0, 139.0], [198.0, 140.0], [198.0, 145.0], [199.0, 146.0], [199.0, 148.0], [200.0, 149.0], [200.0, 151.0], [201.0, 152.0], [201.0, 154.0], [205.0, 159.0], [205.0, 160.0], [206.0, 161.0], [206.0, 164.0], [207.0, 165.0], [207.0, 166.0], [208.0, 166.0], [211.0, 169.0], [232.0, 169.0], [234.0, 167.0], [235.0, 167.0], [236.0, 166.0], [236.0, 164.0], [234.0, 161.0], [233.0, 161.0], [232.0, 160.0], [230.0, 160.0], [229.0, 159.0], [227.0, 159.0], [223.0, 155.0], [218.0, 155.0], [217.0, 154.0], [211.0, 154.0], [210.0, 153.0], [210.0, 149.0], [211.0, 148.0], [210.0, 147.0], [210.0, 145.0], [209.0, 144.0], [209.0, 141.0], [208.0, 140.0], [208.0, 133.0], [210.0, 130.0], [209.0, 127.0], [210.0, 126.0], [210.0, 124.0], [211.0, 123.0], [211.0, 118.0], [210.0, 117.0], [210.0, 116.0], [208.0, 114.0], [208.0, 113.0], [207.0, 112.0], [205.0, 112.0], [205.0, 113.0], [206.0, 113.0], [207.0, 114.0], [207.0, 116.0], [208.0, 117.0], [208.0, 124.0], [206.0, 126.0], [203.0, 126.0], [201.0, 124.0], [201.0, 121.0], [200.0, 120.0], [200.0, 115.0], [199.0, 114.0], [199.0, 112.0], [185.0, 98.0], [185.0, 97.0], [181.0, 93.0], [181.0, 89.0], [180.0, 88.0], [179.0, 85.0], [177.0, 85.0], [176.0, 84.0], [175.0, 84.0], [173.0, 82.0], [173.0, 81.0], [171.0, 79.0], [171.0, 78.0], [168.0, 75.0], [168.0, 74.0], [167.0, 73.0], [166.0, 70.0], [163.0, 67.0], [163.0, 66.0]], 'group_id': None, 'description': '', 'difficult': False, 'shape_type': 'polygon', 'flags': {}, 'attributes': {}}], 'imagePath': 'frame_0295.jpg', 'imageData': None, 'imageHeight': 512, 'imageWidth': 512},
#  /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/Annotations/frame_0295.xml
# xmlfilepath: /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/Annotations/frame_0095.xml
# xmlfilepath: /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/Annotations/frame_0195.xml
# xmlfilepath: /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/Annotations/frame_0295.xml
# labels: ['normal', 'spaghetti', 'possible-spaghetti']

# %%
# 调用函数分离数据集
data_provider.split_dataset(labelme_path, train_val_test_dir,train_ratio, val_ratio, test_ratio)
# Out:
# 数据集分离完成！
# 训练集数量：42
# 验证集数量：12
# 测试集数量：6

# %%
data_provider.move_files(os.path.join(train_val_test_dir, 'train'))
data_provider.move_files(os.path.join(train_val_test_dir, 'val'))
data_provider.move_files(os.path.join(train_val_test_dir, 'test'))
# Out:
# ./datasets/train文件移动完成！
# 总共移动了 42 个PNG文件到images文件夹
# 总共移动了 42 个TXT文件到labels文件夹
# ./datasets/val文件移动完成！
# 总共移动了 12 个PNG文件到images文件夹
# 总共移动了 12 个TXT文件到labels文件夹
# ./datasets/test文件移动完成！
# 总共移动了 6 个PNG文件到images文件夹
# 总共移动了 6 个TXT文件到labels文件夹

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')  # build a new model from scratch
# 下载模型
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
# Use the model
# !yolo task=detect mode=train model=yolov8.yaml data=./datasets/mydata.yaml epochs=200 batch=16 device='cpu'
results = model.train(data='./3d_printer.yaml', epochs=1)  # train the model
results = model.val()  # evaluate model performance on the validation set
# predict
# results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
# Out:
# Ultralytics YOLOv8.2.25 🚀 Python-3.9.19 torch-2.3.0 CPU (Apple M2)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=./3d_printer.yaml, epochs=1, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train10, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train10
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# Model summary: 225 layers, 3011433 parameters, 3011417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/exp/datasets/train/labels... 60 images, 2 backgrounds, 0 corrupt: 100%|██████████| 60/60 [00:00<00:00, 2607.78it/s]
# train: New cache created: /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/exp/datasets/train/labels.cache
# val: Scanning /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/exp/datasets/test/labels... 35 images, 1 backgrounds, 0 corrupt: 100%|██████████| 35/35 [00:00<00:00, 2978.97it/s]
# val: New cache created: /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/exp/datasets/test/labels.cache
# Plotting labels to runs/detect/train10/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/train10
# Starting training for 1 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/1         0G      2.306      4.735      2.047         22        640: 100%|██████████| 4/4 [00:34<00:00,  8.74s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:11<00:00,  5.61s/it]
#                    all         35         34    0.00167      0.368     0.0196    0.00861
#
# 1 epochs completed in 0.013 hours.
# Optimizer stripped from runs/detect/train10/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train10/weights/best.pt, 6.2MB
#
# Validating runs/detect/train10/weights/best.pt...
# Ultralytics YOLOv8.2.25 🚀 Python-3.9.19 torch-2.3.0 CPU (Apple M2)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:10<00:00,  5.37s/it]
#                    all         35         34    0.00167      0.368      0.019     0.0084
#                 normal         35         14   0.000927      0.214    0.00418    0.00173
#              spaghetti         35         18    0.00408      0.889     0.0528     0.0235
#     possible-spaghetti         35          2          0          0          0          0
# Speed: 1.5ms preprocess, 287.9ms inference, 0.0ms loss, 14.1ms postprocess per image
# Results saved to runs/detect/train10
# Ultralytics YOLOv8.2.25 🚀 Python-3.9.19 torch-2.3.0 CPU (Apple M2)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/exp/datasets/test/labels.cache... 35 images, 1 backgrounds, 0 corrupt: 100%|██████████| 35/35 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:10<00:00,  3.53s/it]
#                    all         35         34    0.00167      0.368      0.019     0.0084
#                 normal         35         14   0.000927      0.214    0.00418    0.00173
#              spaghetti         35         18    0.00408      0.889     0.0528     0.0235
#     possible-spaghetti         35          2          0          0          0          0
# Speed: 1.7ms preprocess, 283.0ms inference, 0.0ms loss, 14.2ms postprocess per image
# Results saved to runs/detect/train102

# %%
results = model('/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/')
# Out:
# image 1/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0000.jpg: 640x640 (no detections), 134.0ms
# image 2/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0005.jpg: 640x640 (no detections), 142.3ms
# image 3/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0010.jpg: 640x640 (no detections), 116.0ms
# image 4/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0015.jpg: 640x640 (no detections), 128.5ms
# image 5/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0020.jpg: 640x640 (no detections), 113.3ms
# image 6/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0025.jpg: 640x640 (no detections), 123.4ms
# image 7/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0030.jpg: 640x640 (no detections), 121.8ms
# image 8/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0035.jpg: 640x640 (no detections), 122.8ms
# image 9/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0040.jpg: 640x640 (no detections), 133.4ms
# image 10/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0045.jpg: 640x640 (no detections), 123.6ms
# image 11/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0050.jpg: 640x640 (no detections), 122.1ms
# image 12/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0055.jpg: 640x640 (no detections), 125.1ms
# image 13/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0060.jpg: 640x640 (no detections), 124.7ms
# image 14/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0065.jpg: 640x640 (no detections), 118.8ms
# image 15/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0070.jpg: 640x640 (no detections), 122.7ms
# image 16/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0075.jpg: 640x640 (no detections), 129.8ms
# image 17/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0080.jpg: 640x640 (no detections), 122.4ms
# image 18/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0085.jpg: 640x640 (no detections), 126.3ms
# image 19/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0090.jpg: 640x640 (no detections), 125.9ms
# image 20/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0095.jpg: 640x640 (no detections), 129.0ms
# image 21/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0100.jpg: 640x640 (no detections), 124.7ms
# image 22/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0105.jpg: 640x640 (no detections), 123.8ms
# image 23/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0110.jpg: 640x640 (no detections), 117.7ms
# image 24/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0115.jpg: 640x640 (no detections), 120.9ms
# image 25/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0120.jpg: 640x640 (no detections), 122.9ms
# image 26/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0125.jpg: 640x640 (no detections), 124.2ms
# image 27/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0130.jpg: 640x640 (no detections), 127.1ms
# image 28/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0135.jpg: 640x640 (no detections), 127.2ms
# image 29/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0140.jpg: 640x640 (no detections), 125.9ms
# image 30/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0145.jpg: 640x640 (no detections), 120.1ms
# image 31/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0150.jpg: 640x640 (no detections), 117.5ms
# image 32/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0155.jpg: 640x640 (no detections), 121.2ms
# image 33/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0160.jpg: 640x640 (no detections), 124.9ms
# image 34/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0165.jpg: 640x640 (no detections), 136.3ms
# image 35/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0170.jpg: 640x640 (no detections), 151.4ms
# image 36/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0175.jpg: 640x640 (no detections), 152.1ms
# image 37/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0180.jpg: 640x640 (no detections), 139.0ms
# image 38/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0185.jpg: 640x640 (no detections), 133.5ms
# image 39/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0190.jpg: 640x640 (no detections), 118.9ms
# image 40/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0195.jpg: 640x640 (no detections), 117.6ms
# image 41/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0200.jpg: 640x640 (no detections), 122.8ms
# image 42/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0205.jpg: 640x640 (no detections), 116.4ms
# image 43/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0210.jpg: 640x640 (no detections), 137.7ms
# image 44/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0215.jpg: 640x640 (no detections), 117.4ms
# image 45/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0220.jpg: 640x640 (no detections), 119.1ms
# image 46/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0225.jpg: 640x640 (no detections), 112.8ms
# image 47/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0230.jpg: 640x640 (no detections), 112.0ms
# image 48/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0235.jpg: 640x640 (no detections), 110.3ms
# image 49/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0240.jpg: 640x640 (no detections), 117.2ms
# image 50/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0245.jpg: 640x640 (no detections), 113.4ms
# image 51/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0250.jpg: 640x640 (no detections), 118.6ms
# image 52/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0255.jpg: 640x640 (no detections), 108.9ms
# image 53/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0260.jpg: 640x640 (no detections), 135.0ms
# image 54/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0265.jpg: 640x640 (no detections), 113.5ms
# image 55/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0270.jpg: 640x640 (no detections), 132.8ms
# image 56/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0275.jpg: 640x640 (no detections), 117.3ms
# image 57/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0280.jpg: 640x640 (no detections), 140.0ms
# image 58/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0285.jpg: 640x640 (no detections), 125.4ms
# image 59/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0290.jpg: 640x640 (no detections), 117.7ms
# image 60/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0295.jpg: 640x640 (no detections), 119.6ms
# image 61/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0300.jpg: 640x640 (no detections), 125.5ms
# image 62/62 /Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect/data/frames/spaghetti2/frame_0305.jpg: 640x640 (no detections), 110.8ms
# Speed: 1.8ms preprocess, 124.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)

# %%
results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 51,  40,  48],
#          [ 49,  39,  45],
#          [ 52,  40,  46],
#          ...,
#          [ 31,  22,  25],
#          [ 35,  21,  25],
#          [ 37,  23,  27]],
#
#         [[ 52,  39,  47],
#          [ 49,  37,  43],
#          [ 50,  39,  42],
#          ...,
#          [ 31,  22,  25],
#          [ 33,  22,  25],
#          [ 35,  24,  27]],
#
#         [[ 52,  38,  44],
#          [ 50,  36,  42],
#          [ 50,  36,  40],
#          ...,
#          [ 32,  22,  28],
#          [ 32,  23,  26],
#          [ 33,  24,  27]],
#
#         ...,
#
#         [[127, 122, 131],
#          [125, 122, 131],
#          [128, 125, 134],
#          ...,
#          [129, 128, 132],
#          [126, 125, 129],
#          [128, 127, 131]],
#
#         [[124, 121, 130],
#          [122, 119, 128],
#          [125, 121, 132],
#          ...,
#          [123, 122, 126],
#          [121, 120, 124],
#          [121, 122, 126]],
#
#         [[144, 141, 150],
#          [141, 138, 147],
#          [141, 140, 150],
#          ...,
#          [136, 135, 139],
#          [132, 133, 137],
#          [135, 136, 140]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0000.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 2.566814422607422, 'inference': 126.62601470947266, 'postprocess': 0.32019615173339844},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 56,  35,  37],
#          [ 58,  37,  39],
#          [ 59,  38,  41],
#          ...,
#          [ 31,  25,  30],
#          [ 31,  25,  30],
#          [ 31,  25,  30]],
#
#         [[ 59,  38,  40],
#          [ 58,  37,  39],
#          [ 58,  37,  40],
#          ...,
#          [ 30,  24,  29],
#          [ 32,  26,  31],
#          [ 33,  27,  32]],
#
#         [[ 60,  42,  43],
#          [ 55,  37,  38],
#          [ 54,  35,  38],
#          ...,
#          [ 29,  23,  28],
#          [ 32,  26,  31],
#          [ 34,  28,  33]],
#
#         ...,
#
#         [[126, 123, 132],
#          [125, 122, 131],
#          [125, 122, 131],
#          ...,
#          [131, 126, 135],
#          [130, 125, 134],
#          [129, 124, 133]],
#
#         [[126, 123, 132],
#          [124, 121, 130],
#          [124, 122, 128],
#          ...,
#          [126, 121, 130],
#          [126, 120, 131],
#          [125, 119, 130]],
#
#         [[143, 140, 149],
#          [141, 138, 147],
#          [141, 139, 145],
#          ...,
#          [139, 134, 143],
#          [140, 134, 145],
#          [141, 135, 146]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0005.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.9841194152832031, 'inference': 119.09818649291992, 'postprocess': 0.1697540283203125},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 58,  39,  32],
#          [ 57,  39,  32],
#          [ 58,  39,  34],
#          ...,
#          [ 17,  10,  17],
#          [ 18,  10,  17],
#          [ 17,   9,  16]],
#
#         [[ 57,  38,  31],
#          [ 56,  38,  31],
#          [ 54,  38,  32],
#          ...,
#          [ 18,  11,  18],
#          [ 19,  11,  18],
#          [ 19,  11,  18]],
#
#         [[ 56,  37,  32],
#          [ 53,  37,  31],
#          [ 53,  36,  33],
#          ...,
#          [ 19,  12,  19],
#          [ 21,  13,  20],
#          [ 21,  13,  20]],
#
#         ...,
#
#         [[142, 138, 144],
#          [141, 137, 143],
#          [141, 136, 145],
#          ...,
#          [136, 130, 135],
#          [134, 128, 133],
#          [133, 127, 132]],
#
#         [[143, 138, 147],
#          [142, 137, 146],
#          [139, 136, 145],
#          ...,
#          [129, 125, 130],
#          [128, 125, 127],
#          [127, 124, 126]],
#
#         [[162, 157, 166],
#          [160, 155, 164],
#          [156, 153, 162],
#          ...,
#          [145, 141, 146],
#          [144, 141, 143],
#          [144, 141, 143]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0010.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.7490386962890625, 'inference': 118.69001388549805, 'postprocess': 0.1780986785888672},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 51,  40,  42],
#          [ 53,  42,  44],
#          [ 50,  40,  40],
#          ...,
#          [ 30,  26,  31],
#          [ 26,  25,  29],
#          [ 25,  24,  28]],
#
#         [[ 49,  38,  40],
#          [ 51,  40,  42],
#          [ 49,  39,  39],
#          ...,
#          [ 30,  26,  31],
#          [ 26,  25,  29],
#          [ 25,  24,  28]],
#
#         [[ 49,  36,  38],
#          [ 51,  38,  40],
#          [ 50,  38,  38],
#          ...,
#          [ 29,  25,  30],
#          [ 26,  25,  29],
#          [ 26,  25,  29]],
#
#         ...,
#
#         [[126, 124, 130],
#          [127, 125, 131],
#          [126, 123, 132],
#          ...,
#          [129, 125, 130],
#          [131, 125, 130],
#          [133, 127, 132]],
#
#         [[124, 123, 132],
#          [124, 123, 132],
#          [123, 122, 131],
#          ...,
#          [126, 122, 127],
#          [129, 123, 128],
#          [130, 124, 129]],
#
#         [[141, 140, 149],
#          [141, 140, 149],
#          [139, 138, 147],
#          ...,
#          [141, 137, 142],
#          [144, 138, 143],
#          [146, 140, 145]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0015.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.7108917236328125, 'inference': 123.40903282165527, 'postprocess': 0.19288063049316406},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 59,  43,  44],
#          [ 58,  42,  43],
#          [ 55,  38,  41],
#          ...,
#          [ 19,  16,  18],
#          [ 21,  16,  18],
#          [ 21,  16,  18]],
#
#         [[ 55,  39,  40],
#          [ 55,  39,  40],
#          [ 54,  37,  40],
#          ...,
#          [ 18,  15,  17],
#          [ 21,  16,  18],
#          [ 21,  16,  18]],
#
#         [[ 50,  36,  37],
#          [ 50,  36,  37],
#          [ 51,  37,  39],
#          ...,
#          [ 19,  16,  18],
#          [ 22,  17,  18],
#          [ 22,  17,  18]],
#
#         ...,
#
#         [[137, 132, 141],
#          [138, 133, 142],
#          [138, 133, 142],
#          ...,
#          [138, 134, 139],
#          [138, 135, 137],
#          [139, 136, 138]],
#
#         [[136, 130, 141],
#          [136, 130, 141],
#          [136, 131, 140],
#          ...,
#          [131, 130, 134],
#          [131, 130, 134],
#          [131, 130, 134]],
#
#         [[156, 150, 161],
#          [155, 149, 160],
#          [153, 148, 157],
#          ...,
#          [147, 146, 150],
#          [147, 146, 150],
#          [147, 146, 150]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0020.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 2.4552345275878906, 'inference': 117.9802417755127, 'postprocess': 0.18668174743652344},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 57,  40,  37],
#          [ 57,  40,  37],
#          [ 56,  40,  41],
#          ...,
#          [ 28,  25,  27],
#          [ 27,  26,  30],
#          [ 28,  27,  31]],
#
#         [[ 57,  40,  37],
#          [ 56,  41,  39],
#          [ 57,  41,  42],
#          ...,
#          [ 28,  25,  27],
#          [ 27,  26,  30],
#          [ 28,  27,  31]],
#
#         [[ 55,  40,  38],
#          [ 57,  42,  40],
#          [ 57,  41,  42],
#          ...,
#          [ 28,  24,  29],
#          [ 27,  26,  30],
#          [ 28,  27,  31]],
#
#         ...,
#
#         [[125, 126, 130],
#          [124, 125, 129],
#          [123, 124, 128],
#          ...,
#          [133, 129, 134],
#          [134, 130, 135],
#          [134, 130, 135]],
#
#         [[122, 125, 129],
#          [121, 124, 128],
#          [122, 124, 125],
#          ...,
#          [127, 126, 130],
#          [128, 127, 131],
#          [128, 127, 131]],
#
#         [[139, 142, 146],
#          [138, 141, 145],
#          [139, 141, 142],
#          ...,
#          [144, 143, 147],
#          [144, 143, 147],
#          [144, 143, 147]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0025.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.9612312316894531, 'inference': 124.64308738708496, 'postprocess': 0.2067089080810547},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 59,  43,  37],
#          [ 58,  42,  36],
#          [ 58,  41,  38],
#          ...,
#          [ 28,  22,  27],
#          [ 27,  23,  28],
#          [ 27,  23,  28]],
#
#         [[ 58,  42,  36],
#          [ 57,  41,  35],
#          [ 56,  39,  36],
#          ...,
#          [ 27,  21,  26],
#          [ 26,  22,  27],
#          [ 26,  22,  27]],
#
#         [[ 54,  40,  34],
#          [ 53,  39,  33],
#          [ 53,  38,  35],
#          ...,
#          [ 26,  20,  25],
#          [ 25,  21,  26],
#          [ 25,  21,  26]],
#
#         ...,
#
#         [[145, 141, 146],
#          [145, 141, 146],
#          [145, 141, 146],
#          ...,
#          [133, 130, 132],
#          [133, 130, 132],
#          [133, 130, 132]],
#
#         [[142, 138, 143],
#          [142, 138, 143],
#          [143, 139, 144],
#          ...,
#          [129, 126, 128],
#          [129, 126, 128],
#          [129, 126, 128]],
#
#         [[158, 154, 159],
#          [159, 155, 160],
#          [159, 155, 160],
#          ...,
#          [143, 140, 142],
#          [142, 139, 141],
#          [142, 139, 141]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0030.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.7447471618652344, 'inference': 116.15896224975586, 'postprocess': 0.2880096435546875},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 59,  41,  42],
#          [ 59,  41,  42],
#          [ 53,  36,  39],
#          ...,
#          [ 20,  14,  19],
#          [ 20,  13,  20],
#          [ 21,  14,  21]],
#
#         [[ 58,  40,  41],
#          [ 55,  39,  40],
#          [ 52,  35,  38],
#          ...,
#          [ 20,  14,  19],
#          [ 21,  14,  21],
#          [ 22,  15,  22]],
#
#         [[ 54,  38,  39],
#          [ 52,  36,  37],
#          [ 52,  35,  38],
#          ...,
#          [ 21,  15,  20],
#          [ 22,  15,  22],
#          [ 24,  17,  24]],
#
#         ...,
#
#         [[137, 136, 138],
#          [138, 137, 139],
#          [138, 137, 141],
#          ...,
#          [137, 131, 136],
#          [137, 131, 136],
#          [136, 130, 135]],
#
#         [[136, 135, 137],
#          [136, 135, 137],
#          [137, 136, 138],
#          ...,
#          [133, 128, 130],
#          [132, 126, 131],
#          [131, 125, 130]],
#
#         [[155, 154, 156],
#          [155, 154, 156],
#          [155, 154, 156],
#          ...,
#          [146, 141, 143],
#          [144, 138, 143],
#          [143, 137, 142]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0035.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.8267631530761719, 'inference': 122.00808525085449, 'postprocess': 0.2129077911376953},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 57,  41,  42],
#          [ 57,  41,  42],
#          [ 56,  40,  41],
#          ...,
#          [ 25,  21,  26],
#          [ 26,  22,  27],
#          [ 29,  25,  30]],
#
#         [[ 56,  40,  41],
#          [ 55,  39,  40],
#          [ 54,  38,  39],
#          ...,
#          [ 25,  21,  26],
#          [ 26,  22,  27],
#          [ 28,  24,  29]],
#
#         [[ 56,  40,  41],
#          [ 54,  38,  39],
#          [ 52,  37,  35],
#          ...,
#          [ 27,  21,  26],
#          [ 26,  22,  27],
#          [ 27,  23,  28]],
#
#         ...,
#
#         [[135, 127, 137],
#          [134, 127, 134],
#          [133, 126, 133],
#          ...,
#          [138, 135, 137],
#          [139, 135, 140],
#          [139, 135, 140]],
#
#         [[131, 127, 133],
#          [131, 127, 133],
#          [131, 127, 133],
#          ...,
#          [134, 131, 133],
#          [135, 131, 136],
#          [136, 132, 137]],
#
#         [[148, 144, 150],
#          [149, 145, 151],
#          [149, 145, 150],
#          ...,
#          [149, 146, 148],
#          [150, 146, 151],
#          [150, 146, 151]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0040.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.9986629486083984, 'inference': 121.3529109954834, 'postprocess': 0.18715858459472656},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 61,  40,  43],
#          [ 59,  38,  41],
#          [ 54,  34,  39],
#          ...,
#          [ 17,   8,  18],
#          [ 21,   9,  21],
#          [ 23,  11,  23]],
#
#         [[ 60,  39,  42],
#          [ 56,  37,  40],
#          [ 54,  34,  39],
#          ...,
#          [ 18,   9,  19],
#          [ 22,  10,  22],
#          [ 22,  10,  22]],
#
#         [[ 57,  39,  40],
#          [ 54,  38,  39],
#          [ 52,  35,  38],
#          ...,
#          [ 20,  11,  21],
#          [ 23,  11,  23],
#          [ 23,  11,  23]],
#
#         ...,
#
#         [[141, 138, 140],
#          [141, 138, 140],
#          [141, 138, 140],
#          ...,
#          [132, 128, 134],
#          [132, 128, 134],
#          [133, 129, 135]],
#
#         [[140, 137, 139],
#          [139, 136, 138],
#          [138, 135, 137],
#          ...,
#          [125, 121, 127],
#          [126, 122, 128],
#          [128, 124, 130]],
#
#         [[158, 155, 157],
#          [157, 154, 156],
#          [156, 153, 155],
#          ...,
#          [140, 136, 142],
#          [142, 138, 144],
#          [143, 139, 145]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0045.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.728057861328125, 'inference': 119.41099166870117, 'postprocess': 0.19288063049316406},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 52,  38,  40],
#          [ 55,  41,  43],
#          [ 57,  43,  45],
#          ...,
#          [ 32,  24,  31],
#          [ 30,  24,  29],
#          [ 29,  23,  28]],
#
#         [[ 51,  37,  39],
#          [ 54,  40,  42],
#          [ 55,  41,  43],
#          ...,
#          [ 30,  22,  29],
#          [ 29,  23,  28],
#          [ 28,  22,  27]],
#
#         [[ 51,  37,  39],
#          [ 51,  37,  39],
#          [ 52,  38,  40],
#          ...,
#          [ 28,  20,  27],
#          [ 28,  22,  27],
#          [ 29,  23,  28]],
#
#         ...,
#
#         [[138, 137, 139],
#          [139, 138, 140],
#          [140, 139, 141],
#          ...,
#          [136, 132, 137],
#          [136, 132, 137],
#          [135, 131, 136]],
#
#         [[137, 136, 138],
#          [137, 136, 138],
#          [138, 137, 139],
#          ...,
#          [129, 125, 130],
#          [129, 125, 130],
#          [128, 124, 129]],
#
#         [[157, 156, 158],
#          [156, 155, 157],
#          [155, 154, 156],
#          ...,
#          [144, 140, 145],
#          [144, 140, 145],
#          [144, 140, 145]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0050.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 2.373933792114258, 'inference': 112.13421821594238, 'postprocess': 0.3058910369873047},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 64,  40,  40],
#          [ 62,  38,  38],
#          [ 58,  37,  36],
#          ...,
#          [ 34,  29,  31],
#          [ 35,  30,  32],
#          [ 37,  32,  34]],
#
#         [[ 62,  38,  38],
#          [ 59,  38,  37],
#          [ 58,  37,  36],
#          ...,
#          [ 33,  28,  30],
#          [ 33,  28,  30],
#          [ 35,  30,  32]],
#
#         [[ 58,  37,  36],
#          [ 58,  37,  36],
#          [ 58,  38,  37],
#          ...,
#          [ 32,  26,  31],
#          [ 32,  26,  31],
#          [ 32,  26,  31]],
#
#         ...,
#
#         [[133, 135, 135],
#          [130, 132, 132],
#          [130, 130, 130],
#          ...,
#          [130, 127, 129],
#          [130, 127, 129],
#          [130, 127, 129]],
#
#         [[133, 134, 132],
#          [130, 131, 129],
#          [128, 128, 128],
#          ...,
#          [125, 122, 124],
#          [125, 122, 124],
#          [126, 123, 125]],
#
#         [[151, 152, 150],
#          [147, 148, 146],
#          [145, 145, 145],
#          ...,
#          [140, 137, 139],
#          [141, 138, 140],
#          [141, 138, 140]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0055.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.8889904022216797, 'inference': 111.50002479553223, 'postprocess': 0.1919269561767578},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 55,  36,  39],
#          [ 59,  40,  43],
#          [ 60,  40,  45],
#          ...,
#          [ 29,  25,  31],
#          [ 29,  25,  30],
#          [ 30,  26,  31]],
#
#         [[ 52,  33,  36],
#          [ 55,  36,  39],
#          [ 56,  36,  41],
#          ...,
#          [ 28,  24,  30],
#          [ 28,  24,  29],
#          [ 29,  25,  30]],
#
#         [[ 51,  33,  34],
#          [ 53,  35,  36],
#          [ 52,  35,  38],
#          ...,
#          [ 27,  23,  28],
#          [ 28,  24,  29],
#          [ 30,  26,  31]],
#
#         ...,
#
#         [[127, 123, 129],
#          [128, 124, 130],
#          [126, 122, 128],
#          ...,
#          [130, 127, 129],
#          [126, 125, 127],
#          [127, 126, 128]],
#
#         [[125, 120, 129],
#          [125, 121, 127],
#          [123, 119, 125],
#          ...,
#          [124, 121, 123],
#          [122, 121, 123],
#          [123, 122, 124]],
#
#         [[142, 137, 146],
#          [141, 136, 145],
#          [138, 134, 140],
#          ...,
#          [137, 134, 136],
#          [135, 134, 136],
#          [137, 136, 138]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0060.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.6472339630126953, 'inference': 129.23431396484375, 'postprocess': 0.18095970153808594},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 62,  37,  41],
#          [ 60,  37,  41],
#          [ 53,  36,  39],
#          ...,
#          [ 30,  26,  31],
#          [ 30,  26,  31],
#          [ 28,  24,  29]],
#
#         [[ 61,  36,  40],
#          [ 59,  36,  40],
#          [ 53,  36,  39],
#          ...,
#          [ 30,  26,  31],
#          [ 30,  26,  31],
#          [ 28,  24,  29]],
#
#         [[ 58,  35,  39],
#          [ 57,  36,  39],
#          [ 54,  35,  38],
#          ...,
#          [ 31,  25,  30],
#          [ 31,  25,  30],
#          [ 30,  24,  29]],
#
#         ...,
#
#         [[133, 129, 134],
#          [132, 128, 133],
#          [131, 127, 132],
#          ...,
#          [140, 137, 139],
#          [139, 136, 138],
#          [139, 136, 138]],
#
#         [[132, 129, 131],
#          [131, 128, 130],
#          [130, 127, 129],
#          ...,
#          [134, 131, 133],
#          [134, 131, 133],
#          [134, 131, 133]],
#
#         [[148, 145, 147],
#          [147, 144, 146],
#          [147, 144, 146],
#          ...,
#          [152, 149, 151],
#          [152, 149, 151],
#          [151, 148, 150]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0065.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 2.148151397705078, 'inference': 128.42893600463867, 'postprocess': 0.1919269561767578},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 52,  41,  37],
#          [ 53,  42,  38],
#          [ 53,  41,  41],
#          ...,
#          [ 21,  18,  20],
#          [ 21,  18,  20],
#          [ 22,  19,  21]],
#
#         [[ 53,  41,  37],
#          [ 52,  39,  37],
#          [ 51,  37,  38],
#          ...,
#          [ 20,  17,  19],
#          [ 20,  17,  19],
#          [ 20,  17,  19]],
#
#         [[ 56,  38,  37],
#          [ 54,  36,  35],
#          [ 53,  35,  36],
#          ...,
#          [ 22,  17,  19],
#          [ 21,  16,  18],
#          [ 21,  16,  18]],
#
#         ...,
#
#         [[131, 133, 134],
#          [129, 131, 132],
#          [129, 131, 132],
#          ...,
#          [136, 133, 135],
#          [136, 133, 135],
#          [136, 133, 135]],
#
#         [[133, 134, 138],
#          [128, 129, 133],
#          [128, 127, 131],
#          ...,
#          [130, 129, 131],
#          [131, 130, 132],
#          [131, 130, 132]],
#
#         [[154, 155, 159],
#          [146, 147, 151],
#          [145, 144, 148],
#          ...,
#          [145, 144, 146],
#          [146, 145, 147],
#          [147, 146, 148]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0070.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.7697811126708984, 'inference': 123.65293502807617, 'postprocess': 0.18525123596191406},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 57,  40,  37],
#          [ 57,  40,  37],
#          [ 55,  40,  38],
#          ...,
#          [ 19,  12,  17],
#          [ 21,  11,  17],
#          [ 22,  12,  18]],
#
#         [[ 57,  40,  37],
#          [ 55,  38,  35],
#          [ 53,  38,  36],
#          ...,
#          [ 16,   9,  14],
#          [ 20,  10,  16],
#          [ 21,  11,  17]],
#
#         [[ 57,  40,  37],
#          [ 55,  38,  35],
#          [ 52,  37,  35],
#          ...,
#          [ 14,   8,  13],
#          [ 17,  10,  15],
#          [ 19,  12,  17]],
#
#         ...,
#
#         [[135, 133, 139],
#          [136, 134, 140],
#          [134, 133, 137],
#          ...,
#          [136, 132, 137],
#          [135, 131, 136],
#          [133, 129, 134]],
#
#         [[132, 130, 136],
#          [134, 132, 138],
#          [133, 131, 137],
#          ...,
#          [130, 126, 131],
#          [130, 126, 131],
#          [129, 125, 130]],
#
#         [[143, 141, 147],
#          [146, 144, 150],
#          [147, 145, 151],
#          ...,
#          [145, 141, 146],
#          [145, 141, 146],
#          [144, 140, 145]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0075.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.6160011291503906, 'inference': 122.97201156616211, 'postprocess': 0.29587745666503906},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 62,  40,  42],
#          [ 59,  38,  40],
#          [ 58,  37,  39],
#          ...,
#          [ 17,  13,  19],
#          [ 18,  10,  20],
#          [ 17,   9,  19]],
#
#         [[ 60,  38,  40],
#          [ 58,  37,  39],
#          [ 55,  37,  38],
#          ...,
#          [ 17,  13,  19],
#          [ 18,  10,  20],
#          [ 18,  10,  20]],
#
#         [[ 57,  36,  38],
#          [ 55,  37,  38],
#          [ 55,  37,  38],
#          ...,
#          [ 18,  11,  18],
#          [ 18,  10,  20],
#          [ 18,  10,  20]],
#
#         ...,
#
#         [[138, 135, 144],
#          [139, 136, 145],
#          [139, 137, 143],
#          ...,
#          [134, 131, 133],
#          [134, 131, 133],
#          [135, 133, 133]],
#
#         [[137, 134, 143],
#          [137, 134, 143],
#          [137, 134, 143],
#          ...,
#          [126, 123, 125],
#          [127, 124, 126],
#          [128, 125, 127]],
#
#         [[155, 152, 161],
#          [155, 152, 161],
#          [153, 150, 159],
#          ...,
#          [141, 137, 142],
#          [141, 138, 140],
#          [144, 141, 143]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0080.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.7273426055908203, 'inference': 125.64802169799805, 'postprocess': 0.2498626708984375},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 63,  40,  45],
#          [ 64,  42,  47],
#          [ 62,  41,  49],
#          ...,
#          [ 25,  15,  21],
#          [ 24,  15,  18],
#          [ 23,  14,  17]],
#
#         [[ 62,  39,  44],
#          [ 62,  40,  45],
#          [ 60,  39,  47],
#          ...,
#          [ 25,  15,  21],
#          [ 24,  15,  18],
#          [ 23,  14,  17]],
#
#         [[ 59,  37,  42],
#          [ 59,  37,  42],
#          [ 58,  37,  45],
#          ...,
#          [ 25,  15,  21],
#          [ 24,  15,  18],
#          [ 23,  14,  17]],
#
#         ...,
#
#         [[145, 135, 141],
#          [144, 134, 140],
#          [143, 133, 139],
#          ...,
#          [132, 127, 136],
#          [133, 128, 137],
#          [134, 129, 138]],
#
#         [[146, 135, 138],
#          [143, 134, 137],
#          [143, 134, 137],
#          ...,
#          [129, 123, 134],
#          [130, 124, 135],
#          [130, 124, 135]],
#
#         [[163, 152, 155],
#          [163, 152, 155],
#          [161, 152, 155],
#          ...,
#          [145, 139, 150],
#          [145, 139, 150],
#          [146, 140, 151]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0085.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 2.0241737365722656, 'inference': 113.03424835205078, 'postprocess': 0.17404556274414062},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 59,  43,  37],
#          [ 57,  41,  35],
#          [ 53,  39,  33],
#          ...,
#          [ 32,  18,  29],
#          [ 33,  16,  29],
#          [ 31,  14,  27]],
#
#         [[ 57,  41,  35],
#          [ 56,  40,  34],
#          [ 52,  38,  32],
#          ...,
#          [ 32,  18,  29],
#          [ 32,  15,  28],
#          [ 30,  13,  26]],
#
#         [[ 55,  39,  33],
#          [ 55,  39,  33],
#          [ 52,  37,  34],
#          ...,
#          [ 30,  19,  27],
#          [ 31,  17,  28],
#          [ 29,  15,  26]],
#
#         ...,
#
#         [[125, 124, 134],
#          [128, 127, 137],
#          [131, 128, 137],
#          ...,
#          [141, 137, 142],
#          [141, 137, 143],
#          [141, 137, 143]],
#
#         [[127, 126, 136],
#          [127, 126, 136],
#          [127, 126, 136],
#          ...,
#          [134, 130, 135],
#          [134, 130, 136],
#          [134, 130, 136]],
#
#         [[147, 146, 156],
#          [145, 144, 154],
#          [143, 142, 152],
#          ...,
#          [150, 146, 151],
#          [150, 146, 152],
#          [150, 146, 152]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0090.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.5559196472167969, 'inference': 113.6929988861084, 'postprocess': 0.3628730773925781},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 62,  39,  47],
#          [ 59,  38,  46],
#          [ 58,  38,  43],
#          ...,
#          [ 31,  23,  33],
#          [ 31,  23,  30],
#          [ 31,  23,  30]],
#
#         [[ 58,  35,  43],
#          [ 56,  35,  43],
#          [ 56,  36,  41],
#          ...,
#          [ 30,  23,  30],
#          [ 31,  23,  30],
#          [ 31,  23,  30]],
#
#         [[ 57,  35,  40],
#          [ 56,  36,  41],
#          [ 56,  36,  41],
#          ...,
#          [ 28,  24,  30],
#          [ 30,  23,  30],
#          [ 30,  24,  29]],
#
#         ...,
#
#         [[126, 123, 132],
#          [125, 122, 131],
#          [123, 121, 127],
#          ...,
#          [135, 129, 134],
#          [135, 129, 134],
#          [135, 129, 134]],
#
#         [[124, 123, 132],
#          [122, 121, 130],
#          [120, 120, 126],
#          ...,
#          [132, 126, 131],
#          [133, 126, 131],
#          [134, 127, 132]],
#
#         [[141, 140, 149],
#          [139, 138, 147],
#          [137, 137, 143],
#          ...,
#          [144, 138, 143],
#          [145, 138, 143],
#          [146, 139, 144]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0095.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.5208721160888672, 'inference': 119.52781677246094, 'postprocess': 0.26488304138183594},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 59,  43,  44],
#          [ 54,  38,  39],
#          [ 55,  41,  42],
#          ...,
#          [ 33,  25,  32],
#          [ 35,  25,  31],
#          [ 36,  24,  30]],
#
#         [[ 54,  38,  39],
#          [ 50,  34,  35],
#          [ 51,  37,  38],
#          ...,
#          [ 31,  25,  30],
#          [ 34,  24,  30],
#          [ 36,  24,  30]],
#
#         [[ 49,  35,  36],
#          [ 47,  33,  34],
#          [ 48,  34,  35],
#          ...,
#          [ 31,  26,  28],
#          [ 34,  25,  28],
#          [ 35,  26,  29]],
#
#         ...,
#
#         [[123, 119, 124],
#          [122, 118, 123],
#          [121, 117, 122],
#          ...,
#          [130, 127, 129],
#          [129, 126, 128],
#          [129, 126, 128]],
#
#         [[121, 120, 124],
#          [119, 118, 122],
#          [118, 117, 121],
#          ...,
#          [124, 121, 123],
#          [124, 121, 123],
#          [125, 122, 124]],
#
#         [[139, 138, 142],
#          [136, 135, 139],
#          [134, 133, 137],
#          ...,
#          [137, 134, 136],
#          [138, 135, 137],
#          [140, 137, 139]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0100.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.5559196472167969, 'inference': 115.99993705749512, 'postprocess': 0.18215179443359375},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 63,  42,  45],
#          [ 57,  38,  41],
#          [ 54,  35,  38],
#          ...,
#          [ 33,  22,  25],
#          [ 34,  23,  26],
#          [ 36,  25,  28]],
#
#         [[ 63,  42,  45],
#          [ 59,  38,  41],
#          [ 55,  36,  39],
#          ...,
#          [ 32,  21,  24],
#          [ 33,  22,  25],
#          [ 35,  24,  27]],
#
#         [[ 60,  37,  41],
#          [ 57,  36,  39],
#          [ 56,  35,  38],
#          ...,
#          [ 33,  21,  27],
#          [ 31,  21,  27],
#          [ 33,  23,  29]],
#
#         ...,
#
#         [[132, 128, 133],
#          [131, 127, 132],
#          [131, 127, 132],
#          ...,
#          [130, 127, 129],
#          [132, 129, 131],
#          [132, 129, 131]],
#
#         [[130, 126, 132],
#          [129, 125, 131],
#          [128, 124, 129],
#          ...,
#          [129, 126, 128],
#          [129, 126, 128],
#          [128, 125, 127]],
#
#         [[151, 147, 153],
#          [149, 145, 151],
#          [146, 142, 147],
#          ...,
#          [143, 140, 142],
#          [141, 138, 140],
#          [138, 135, 137]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0105.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.631021499633789, 'inference': 112.7769947052002, 'postprocess': 0.17595291137695312},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 57,  40,  37],
#          [ 60,  43,  40],
#          [ 57,  39,  38],
#          ...,
#          [ 26,  20,  25],
#          [ 26,  20,  25],
#          [ 27,  21,  26]],
#
#         [[ 56,  39,  36],
#          [ 58,  41,  38],
#          [ 55,  37,  36],
#          ...,
#          [ 26,  20,  25],
#          [ 26,  20,  25],
#          [ 27,  21,  26]],
#
#         [[ 57,  37,  36],
#          [ 58,  38,  37],
#          [ 53,  35,  34],
#          ...,
#          [ 25,  19,  24],
#          [ 26,  20,  25],
#          [ 28,  22,  27]],
#
#         ...,
#
#         [[138, 136, 142],
#          [137, 135, 141],
#          [137, 136, 140],
#          ...,
#          [136, 132, 137],
#          [138, 132, 137],
#          [137, 131, 136]],
#
#         [[136, 134, 140],
#          [136, 134, 140],
#          [135, 134, 138],
#          ...,
#          [129, 125, 130],
#          [131, 125, 130],
#          [131, 125, 130]],
#
#         [[153, 151, 157],
#          [152, 150, 156],
#          [152, 151, 155],
#          ...,
#          [143, 139, 144],
#          [146, 140, 145],
#          [146, 140, 145]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0110.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.8761157989501953, 'inference': 118.90983581542969, 'postprocess': 0.1850128173828125},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 60,  37,  41],
#          [ 59,  38,  41],
#          [ 59,  38,  41],
#          ...,
#          [ 16,  14,  20],
#          [ 17,  12,  21],
#          [ 17,  12,  21]],
#
#         [[ 60,  37,  41],
#          [ 59,  38,  41],
#          [ 57,  38,  41],
#          ...,
#          [ 16,  14,  20],
#          [ 18,  13,  22],
#          [ 17,  12,  21]],
#
#         [[ 58,  37,  40],
#          [ 58,  37,  40],
#          [ 56,  37,  40],
#          ...,
#          [ 18,  14,  20],
#          [ 18,  13,  22],
#          [ 17,  12,  21]],
#
#         ...,
#
#         [[142, 140, 140],
#          [141, 139, 139],
#          [137, 136, 138],
#          ...,
#          [135, 129, 134],
#          [134, 130, 135],
#          [135, 131, 136]],
#
#         [[137, 136, 138],
#          [135, 134, 136],
#          [133, 132, 134],
#          ...,
#          [128, 122, 127],
#          [129, 123, 128],
#          [132, 126, 131]],
#
#         [[155, 154, 156],
#          [153, 152, 154],
#          [151, 150, 152],
#          ...,
#          [143, 137, 142],
#          [144, 138, 143],
#          [147, 141, 146]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0115.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.5797615051269531, 'inference': 136.4150047302246, 'postprocess': 0.19812583923339844},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 63,  42,  40],
#          [ 58,  37,  35],
#          [ 57,  35,  37],
#          ...,
#          [ 15,  12,  21],
#          [ 18,  13,  22],
#          [ 19,  14,  23]],
#
#         [[ 60,  41,  38],
#          [ 55,  36,  33],
#          [ 54,  33,  35],
#          ...,
#          [ 15,  12,  21],
#          [ 18,  13,  22],
#          [ 19,  14,  23]],
#
#         [[ 57,  40,  37],
#          [ 52,  35,  32],
#          [ 52,  34,  35],
#          ...,
#          [ 17,  13,  19],
#          [ 18,  14,  20],
#          [ 19,  15,  21]],
#
#         ...,
#
#         [[135, 131, 136],
#          [135, 131, 136],
#          [134, 130, 136],
#          ...,
#          [134, 130, 136],
#          [134, 130, 136],
#          [134, 130, 136]],
#
#         [[133, 129, 134],
#          [133, 129, 134],
#          [133, 129, 135],
#          ...,
#          [129, 124, 133],
#          [129, 124, 133],
#          [129, 124, 133]],
#
#         [[149, 145, 150],
#          [150, 146, 151],
#          [151, 147, 153],
#          ...,
#          [141, 136, 145],
#          [141, 136, 145],
#          [140, 135, 144]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0120.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.6551017761230469, 'inference': 126.69587135314941, 'postprocess': 0.1850128173828125},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 60,  44,  45],
#          [ 57,  41,  42],
#          [ 57,  41,  42],
#          ...,
#          [ 20,  11,  21],
#          [ 21,  13,  20],
#          [ 22,  14,  21]],
#
#         [[ 55,  39,  40],
#          [ 52,  36,  37],
#          [ 52,  36,  37],
#          ...,
#          [ 20,  12,  19],
#          [ 21,  13,  20],
#          [ 21,  13,  20]],
#
#         [[ 55,  38,  41],
#          [ 51,  34,  37],
#          [ 50,  33,  36],
#          ...,
#          [ 19,  11,  18],
#          [ 22,  11,  19],
#          [ 22,  12,  18]],
#
#         ...,
#
#         [[138, 133, 135],
#          [137, 132, 134],
#          [133, 130, 132],
#          ...,
#          [135, 131, 136],
#          [135, 131, 136],
#          [136, 132, 137]],
#
#         [[137, 132, 133],
#          [136, 131, 132],
#          [132, 130, 130],
#          ...,
#          [128, 124, 129],
#          [128, 124, 129],
#          [128, 124, 129]],
#
#         [[154, 150, 149],
#          [153, 149, 148],
#          [149, 147, 147],
#          ...,
#          [143, 139, 144],
#          [142, 138, 143],
#          [141, 137, 142]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0125.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.561880111694336, 'inference': 141.85595512390137, 'postprocess': 0.2651214599609375},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 59,  39,  38],
#          [ 59,  39,  38],
#          [ 60,  40,  39],
#          ...,
#          [ 15,  11,  16],
#          [ 16,  12,  17],
#          [ 16,  12,  17]],
#
#         [[ 56,  36,  35],
#          [ 56,  36,  35],
#          [ 57,  37,  36],
#          ...,
#          [ 16,  12,  17],
#          [ 16,  12,  17],
#          [ 17,  13,  18]],
#
#         [[ 56,  38,  37],
#          [ 56,  38,  37],
#          [ 55,  37,  38],
#          ...,
#          [ 15,  11,  16],
#          [ 16,  12,  17],
#          [ 16,  12,  17]],
#
#         ...,
#
#         [[133, 128, 130],
#          [133, 128, 130],
#          [133, 127, 132],
#          ...,
#          [134, 130, 135],
#          [135, 131, 136],
#          [136, 132, 137]],
#
#         [[131, 128, 130],
#          [130, 127, 129],
#          [130, 126, 131],
#          ...,
#          [128, 124, 129],
#          [129, 125, 130],
#          [130, 126, 131]],
#
#         [[148, 145, 147],
#          [147, 144, 146],
#          [145, 141, 146],
#          ...,
#          [146, 142, 147],
#          [147, 143, 148],
#          [147, 143, 148]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0130.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.8630027770996094, 'inference': 131.57200813293457, 'postprocess': 0.22292137145996094},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 59,  43,  44],
#          [ 57,  41,  42],
#          [ 60,  41,  44],
#          ...,
#          [ 22,  15,  20],
#          [ 24,  14,  20],
#          [ 20,  10,  16]],
#
#         [[ 58,  42,  43],
#          [ 54,  38,  39],
#          [ 55,  36,  39],
#          ...,
#          [ 20,  13,  18],
#          [ 22,  12,  18],
#          [ 21,  11,  17]],
#
#         [[ 54,  41,  39],
#          [ 50,  37,  35],
#          [ 51,  35,  36],
#          ...,
#          [ 18,  11,  16],
#          [ 21,  11,  17],
#          [ 22,  12,  18]],
#
#         ...,
#
#         [[129, 128, 132],
#          [128, 127, 131],
#          [127, 126, 130],
#          ...,
#          [135, 132, 134],
#          [134, 131, 133],
#          [133, 130, 132]],
#
#         [[124, 125, 129],
#          [124, 125, 129],
#          [125, 124, 128],
#          ...,
#          [130, 127, 129],
#          [131, 126, 128],
#          [131, 126, 128]],
#
#         [[140, 141, 145],
#          [140, 141, 145],
#          [141, 140, 144],
#          ...,
#          [146, 143, 145],
#          [148, 143, 145],
#          [148, 143, 145]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0135.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.867055892944336, 'inference': 133.3940029144287, 'postprocess': 0.1819133758544922},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 59,  39,  34],
#          [ 57,  36,  34],
#          [ 58,  38,  37],
#          ...,
#          [ 23,  17,  22],
#          [ 24,  19,  21],
#          [ 25,  20,  22]],
#
#         [[ 57,  37,  32],
#          [ 58,  37,  35],
#          [ 59,  39,  38],
#          ...,
#          [ 22,  16,  21],
#          [ 23,  18,  20],
#          [ 25,  20,  22]],
#
#         [[ 52,  32,  27],
#          [ 55,  34,  32],
#          [ 58,  38,  37],
#          ...,
#          [ 23,  16,  21],
#          [ 24,  17,  20],
#          [ 26,  19,  22]],
#
#         ...,
#
#         [[129, 123, 128],
#          [128, 122, 127],
#          [129, 123, 128],
#          ...,
#          [140, 137, 139],
#          [140, 137, 139],
#          [140, 137, 139]],
#
#         [[129, 123, 128],
#          [127, 121, 126],
#          [127, 121, 126],
#          ...,
#          [135, 132, 134],
#          [136, 133, 135],
#          [135, 132, 134]],
#
#         [[146, 140, 145],
#          [144, 138, 143],
#          [143, 137, 142],
#          ...,
#          [148, 145, 147],
#          [148, 145, 147],
#          [148, 145, 147]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0140.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.7321109771728516, 'inference': 115.68284034729004, 'postprocess': 0.1850128173828125},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 59,  43,  44],
#          [ 59,  43,  44],
#          [ 57,  40,  43],
#          ...,
#          [ 29,  24,  25],
#          [ 30,  23,  26],
#          [ 31,  24,  27]],
#
#         [[ 57,  41,  42],
#          [ 57,  41,  42],
#          [ 56,  39,  42],
#          ...,
#          [ 29,  24,  25],
#          [ 30,  23,  26],
#          [ 31,  24,  27]],
#
#         [[ 53,  37,  38],
#          [ 54,  38,  39],
#          [ 54,  37,  40],
#          ...,
#          [ 29,  24,  25],
#          [ 30,  23,  26],
#          [ 31,  24,  27]],
#
#         ...,
#
#         [[123, 120, 129],
#          [124, 121, 130],
#          [124, 122, 128],
#          ...,
#          [136, 133, 135],
#          [136, 133, 135],
#          [136, 133, 135]],
#
#         [[122, 119, 128],
#          [123, 120, 129],
#          [122, 120, 126],
#          ...,
#          [132, 129, 131],
#          [132, 130, 130],
#          [132, 130, 130]],
#
#         [[140, 137, 146],
#          [141, 138, 147],
#          [141, 139, 145],
#          ...,
#          [147, 144, 146],
#          [147, 145, 145],
#          [147, 145, 145]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0145.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.5270709991455078, 'inference': 122.85494804382324, 'postprocess': 0.20599365234375},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 57,  39,  38],
#          [ 56,  38,  37],
#          [ 53,  37,  38],
#          ...,
#          [ 29,  23,  28],
#          [ 29,  23,  28],
#          [ 29,  23,  28]],
#
#         [[ 56,  38,  37],
#          [ 53,  38,  36],
#          [ 52,  36,  37],
#          ...,
#          [ 29,  23,  28],
#          [ 29,  23,  28],
#          [ 29,  23,  28]],
#
#         [[ 54,  38,  39],
#          [ 52,  36,  37],
#          [ 52,  35,  38],
#          ...,
#          [ 30,  24,  29],
# ...
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 2.214193344116211, 'inference': 125.99897384643555, 'postprocess': 0.19097328186035156},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 60,  43,  46],
#          [ 57,  40,  43],
#          [ 53,  36,  39],
#          ...,
#          [ 22,  19,  21],
#          [ 25,  20,  22],
#          [ 26,  21,  23]],
#
#         [[ 57,  40,  43],
#          [ 56,  39,  42],
#          [ 53,  36,  39],
#          ...,
#          [ 21,  18,  20],
#          [ 24,  19,  21],
#          [ 25,  20,  22]],
#
#         [[ 54,  38,  39],
#          [ 55,  39,  40],
#          [ 51,  37,  38],
#          ...,
#          [ 22,  19,  21],
#          [ 24,  19,  21],
#          [ 24,  19,  21]],
#
#         ...,
#
#         [[111, 110, 112],
#          [112, 111, 113],
#          [113, 112, 114],
#          ...,
#          [136, 129, 134],
#          [138, 128, 134],
#          [138, 128, 134]],
#
#         [[106, 108, 108],
#          [107, 109, 109],
#          [110, 110, 110],
#          ...,
#          [131, 123, 130],
#          [133, 122, 130],
#          [134, 123, 131]],
#
#         [[120, 122, 122],
#          [120, 122, 122],
#          [123, 123, 123],
#          ...,
#          [147, 139, 146],
#          [149, 138, 148],
#          [150, 139, 149]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0260.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.8820762634277344, 'inference': 119.46511268615723, 'postprocess': 0.1862049102783203},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 49,  38,  40],
#          [ 51,  40,  42],
#          [ 51,  40,  43],
#          ...,
#          [ 25,  18,  23],
#          [ 26,  20,  25],
#          [ 28,  22,  27]],
#
#         [[ 50,  39,  41],
#          [ 50,  39,  41],
#          [ 49,  38,  41],
#          ...,
#          [ 26,  19,  24],
#          [ 27,  20,  25],
#          [ 28,  22,  27]],
#
#         [[ 52,  39,  41],
#          [ 51,  38,  40],
#          [ 50,  37,  39],
#          ...,
#          [ 28,  18,  24],
#          [ 29,  19,  25],
#          [ 29,  22,  27]],
#
#         ...,
#
#         [[109, 108, 110],
#          [110, 109, 111],
#          [112, 109, 111],
#          ...,
#          [133, 130, 132],
#          [132, 129, 131],
#          [132, 129, 131]],
#
#         [[108, 105, 107],
#          [108, 105, 107],
#          [108, 106, 106],
#          ...,
#          [129, 126, 128],
#          [128, 125, 127],
#          [128, 125, 127]],
#
#         [[123, 120, 122],
#          [122, 119, 121],
#          [121, 119, 119],
#          ...,
#          [144, 141, 143],
#          [143, 140, 142],
#          [144, 141, 143]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0265.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.7580986022949219, 'inference': 119.67802047729492, 'postprocess': 0.1761913299560547},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 51,  39,  39],
#          [ 51,  39,  39],
#          [ 53,  39,  41],
#          ...,
#          [ 27,  21,  26],
#          [ 27,  22,  24],
#          [ 24,  19,  21]],
#
#         [[ 50,  38,  38],
#          [ 50,  38,  38],
#          [ 52,  38,  40],
#          ...,
#          [ 27,  21,  26],
#          [ 26,  21,  23],
#          [ 25,  20,  22]],
#
#         [[ 50,  36,  38],
#          [ 50,  36,  38],
#          [ 53,  36,  39],
#          ...,
#          [ 28,  21,  26],
#          [ 28,  21,  24],
#          [ 27,  20,  23]],
#
#         ...,
#
#         [[110, 108, 114],
#          [111, 109, 115],
#          [111, 109, 115],
#          ...,
#          [133, 132, 134],
#          [132, 131, 133],
#          [132, 131, 133]],
#
#         [[105, 106, 110],
#          [106, 107, 111],
#          [106, 107, 111],
#          ...,
#          [129, 128, 130],
#          [128, 127, 129],
#          [128, 127, 129]],
#
#         [[118, 119, 123],
#          [119, 120, 124],
#          [120, 121, 125],
#          ...,
#          [143, 142, 144],
#          [142, 141, 143],
#          [142, 141, 143]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0270.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.8188953399658203, 'inference': 115.36288261413574, 'postprocess': 0.308990478515625},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 56,  36,  41],
#          [ 57,  37,  42],
#          [ 56,  39,  42],
#          ...,
#          [ 30,  19,  27],
#          [ 30,  19,  27],
#          [ 31,  20,  28]],
#
#         [[ 53,  33,  38],
#          [ 54,  35,  38],
#          [ 54,  37,  40],
#          ...,
#          [ 30,  19,  27],
#          [ 30,  19,  27],
#          [ 30,  19,  27]],
#
#         [[ 51,  34,  37],
#          [ 51,  34,  37],
#          [ 53,  36,  39],
#          ...,
#          [ 31,  21,  27],
#          [ 30,  19,  27],
#          [ 29,  18,  26]],
#
#         ...,
#
#         [[113, 107, 118],
#          [111, 106, 115],
#          [110, 105, 114],
#          ...,
#          [137, 131, 136],
#          [135, 128, 135],
#          [134, 127, 134]],
#
#         [[111, 103, 114],
#          [110, 102, 112],
#          [107, 102, 111],
#          ...,
#          [133, 127, 132],
#          [132, 125, 132],
#          [131, 124, 131]],
#
#         [[125, 117, 128],
#          [124, 116, 126],
#          [122, 117, 126],
#          ...,
#          [146, 140, 145],
#          [146, 139, 146],
#          [147, 140, 147]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0275.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.8601417541503906, 'inference': 108.64996910095215, 'postprocess': 0.2040863037109375},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 50,  38,  38],
#          [ 51,  39,  39],
#          [ 51,  41,  41],
#          ...,
#          [ 32,  25,  30],
#          [ 29,  23,  28],
#          [ 28,  22,  27]],
#
#         [[ 50,  38,  38],
#          [ 51,  39,  39],
#          [ 52,  40,  40],
#          ...,
#          [ 31,  24,  29],
#          [ 28,  22,  27],
#          [ 28,  22,  27]],
#
#         [[ 52,  38,  39],
#          [ 51,  39,  39],
#          [ 51,  39,  39],
#          ...,
#          [ 30,  23,  28],
#          [ 29,  22,  27],
#          [ 30,  23,  28]],
#
#         ...,
#
#         [[123, 121, 127],
#          [123, 121, 127],
#          [124, 122, 128],
#          ...,
#          [134, 131, 133],
#          [133, 130, 132],
#          [132, 129, 131]],
#
#         [[121, 119, 125],
#          [120, 118, 124],
#          [120, 118, 124],
#          ...,
#          [129, 126, 128],
#          [127, 124, 126],
#          [125, 122, 124]],
#
#         [[135, 133, 139],
#          [133, 131, 137],
#          [132, 130, 136],
#          ...,
#          [145, 142, 144],
#          [143, 140, 142],
#          [141, 138, 140]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0280.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.4560222625732422, 'inference': 113.77596855163574, 'postprocess': 0.17189979553222656},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 56,  42,  46],
#          [ 55,  41,  45],
#          [ 54,  39,  43],
#          ...,
#          [ 30,  23,  30],
#          [ 29,  22,  29],
#          [ 28,  21,  28]],
#
#         [[ 53,  39,  43],
#          [ 53,  39,  43],
#          [ 53,  38,  42],
#          ...,
#          [ 30,  23,  30],
#          [ 29,  22,  29],
#          [ 29,  22,  29]],
#
#         [[ 50,  37,  39],
#          [ 50,  37,  39],
#          [ 49,  36,  38],
#          ...,
#          [ 31,  24,  29],
#          [ 31,  23,  30],
#          [ 31,  23,  30]],
#
#         ...,
#
#         [[121, 118, 127],
#          [120, 117, 126],
#          [122, 117, 126],
#          ...,
#          [134, 130, 135],
#          [134, 130, 136],
#          [133, 129, 135]],
#
#         [[118, 115, 124],
#          [117, 114, 123],
#          [117, 114, 123],
#          ...,
#          [129, 128, 132],
#          [128, 126, 132],
#          [127, 125, 131]],
#
#         [[133, 130, 139],
#          [132, 129, 138],
#          [131, 128, 137],
#          ...,
#          [142, 143, 147],
#          [143, 141, 147],
#          [142, 140, 146]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0285.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.981973648071289, 'inference': 114.64977264404297, 'postprocess': 0.23102760314941406},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 62,  44,  45],
#          [ 60,  44,  45],
#          [ 57,  43,  44],
#          ...,
#          [ 30,  25,  27],
#          [ 30,  23,  26],
#          [ 31,  22,  25]],
#
#         [[ 57,  39,  40],
#          [ 56,  40,  41],
#          [ 54,  40,  41],
#          ...,
#          [ 29,  24,  26],
#          [ 29,  22,  25],
#          [ 31,  22,  25]],
#
#         [[ 57,  38,  41],
#          [ 55,  38,  41],
#          [ 52,  38,  40],
#          ...,
#          [ 28,  23,  25],
#          [ 29,  22,  25],
#          [ 31,  22,  25]],
#
#         ...,
#
#         [[118, 114, 119],
#          [118, 114, 119],
#          [118, 114, 119],
#          ...,
#          [131, 127, 132],
#          [131, 127, 132],
#          [130, 126, 131]],
#
#         [[114, 110, 115],
#          [115, 111, 116],
#          [115, 112, 114],
#          ...,
#          [124, 120, 125],
#          [124, 120, 125],
#          [124, 120, 125]],
#
#         [[128, 124, 129],
#          [129, 125, 130],
#          [129, 126, 128],
#          ...,
#          [139, 135, 140],
#          [139, 135, 140],
#          [139, 135, 140]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0290.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.806020736694336, 'inference': 113.00396919250488, 'postprocess': 0.21409988403320312},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 59,  44,  48],
#          [ 55,  40,  44],
#          [ 54,  40,  42],
#          ...,
#          [ 30,  23,  30],
#          [ 30,  22,  33],
#          [ 29,  21,  32]],
#
#         [[ 55,  40,  44],
#          [ 53,  38,  42],
#          [ 52,  38,  40],
#          ...,
#          [ 30,  23,  30],
#          [ 29,  21,  31],
#          [ 29,  21,  32]],
#
#         [[ 50,  35,  39],
#          [ 50,  35,  39],
#          [ 50,  36,  38],
#          ...,
#          [ 29,  22,  29],
#          [ 30,  21,  31],
#          [ 30,  21,  31]],
#
#         ...,
#
#         [[112, 108, 114],
#          [112, 108, 114],
#          [112, 108, 114],
#          ...,
#          [131, 128, 130],
#          [132, 127, 129],
#          [131, 126, 128]],
#
#         [[110, 106, 112],
#          [110, 106, 112],
#          [110, 106, 112],
#          ...,
#          [129, 123, 128],
#          [130, 123, 128],
#          [130, 123, 128]],
#
#         [[120, 116, 122],
#          [120, 116, 122],
#          [121, 117, 123],
#          ...,
#          [142, 136, 141],
#          [144, 137, 142],
#          [145, 138, 143]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0295.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.7468929290771484, 'inference': 117.91205406188965, 'postprocess': 0.1938343048095703},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 53,  42,  38],
#          [ 52,  41,  37],
#          [ 54,  38,  39],
#          ...,
#          [ 34,  25,  28],
#          [ 31,  24,  27],
#          [ 31,  24,  27]],
#
#         [[ 51,  40,  36],
#          [ 51,  38,  36],
#          [ 52,  36,  37],
#          ...,
#          [ 33,  24,  27],
#          [ 30,  23,  26],
#          [ 30,  23,  26]],
#
#         [[ 50,  37,  35],
#          [ 50,  37,  35],
#          [ 51,  35,  36],
#          ...,
#          [ 30,  23,  26],
#          [ 29,  22,  25],
#          [ 30,  23,  26]],
#
#         ...,
#
#         [[112, 109, 111],
#          [111, 108, 110],
#          [111, 109, 109],
#          ...,
#          [130, 127, 129],
#          [129, 126, 128],
#          [131, 128, 130]],
#
#         [[107, 104, 106],
#          [108, 105, 107],
#          [107, 104, 106],
#          ...,
#          [124, 120, 125],
#          [124, 121, 123],
#          [127, 124, 126]],
#
#         [[120, 117, 119],
#          [121, 118, 120],
#          [121, 118, 120],
#          ...,
#          [139, 135, 140],
#          [141, 138, 140],
#          [145, 142, 144]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0300.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 1.5079975128173828, 'inference': 121.97518348693848, 'postprocess': 0.23603439331054688},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'normal', 1: 'spaghetti', 2: 'possible-spaghetti'}
#  obb: None
#  orig_img: array([[[ 65,  38,  34],
#          [ 61,  36,  34],
#          [ 60,  34,  34],
#          ...,
#          [ 20,  13,  18],
#          [ 20,  13,  18],
#          [ 21,  14,  19]],
#
#         [[ 63,  36,  32],
#          [ 60,  35,  33],
#          [ 58,  34,  34],
#          ...,
#          [ 21,  14,  19],
#          [ 21,  14,  19],
#          [ 22,  15,  20]],
#
#         [[ 59,  34,  30],
#          [ 57,  34,  32],
#          [ 56,  35,  34],
#          ...,
#          [ 20,  13,  18],
#          [ 21,  14,  19],
#          [ 23,  16,  21]],
#
#         ...,
#
#         [[111, 106, 108],
#          [113, 108, 110],
#          [110, 107, 109],
#          ...,
#          [134, 131, 133],
#          [135, 132, 134],
#          [135, 132, 134]],
#
#         [[106, 104, 104],
#          [107, 105, 105],
#          [106, 104, 104],
#          ...,
#          [128, 125, 127],
#          [128, 125, 127],
#          [128, 125, 127]],
#
#         [[122, 120, 120],
#          [123, 121, 121],
#          [121, 119, 119],
#          ...,
#          [144, 141, 143],
#          [144, 141, 143],
#          [144, 141, 143]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/Users/max/Documents/06_john_doc/3d_p/3DAnomalyDetect-main/data/frames/spaghetti2/frame_0305.jpg'
#  probs: None
#  save_dir: 'runs/detect/train73'
#  speed: {'preprocess': 2.115011215209961, 'inference': 122.44987487792969, 'postprocess': 0.18095970153808594}]
